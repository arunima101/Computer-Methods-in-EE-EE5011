# %%
import numpy as np
from math import *
import scipy.special as sp
import matplotlib.pyplot as plt

# %% [markdown]
#  ## Minimization of Nice function

# %%
def func_ND(parameter):
    x,y,z=parameter
    return 1.5-sp.jv(0,(5*(x-0.5)**2 + (0.5*x+y-0.5)**2 + 0.2*(0.25*x+0.5*y+z-0.5)**2))

# %% [markdown]
# ### $Powell's$ $Algorithm$

# %%
def golden_ratio(function, e, current, a, b, tolerance):
    c = (3 - sqrt(5)) / 2
    x1 = a + (b - a) * c
    x2 = a + b - x1

    fx1 = function(current + x1 * e)
    fx2 = function(current + x2 * e)

    while b - a > tolerance:
        if fx1 <= fx2:
            b = x2
            x2 = x1
            fx2 = fx1
            x1 = a + c * (b - a)
            fx1 = function(current + x1 * e)
            x = x1
        else:
            a = x1
            x1 = x2
            fx1 = fx2
            x2 = b - c * (b - a)
            fx2 = function(current + x2 * e)
            x = x2

    return x

# %%
def powell(function, helper_function, starting_position, tolerance, display_info=False, window=None, gda=0, gdb=1):
    dimension = starting_position.size
    e = np.eye(dimension)
    x = starting_position
    x1 = starting_position + 2 * 10
    num_iterations = 0
    minlist=[]

    while np.max(np.abs(x - x1)) > tolerance:
        num_iterations += 1
        current = x
        for i in range(dimension):
            theta = helper_function(function, e[:, i], current, gda, gdb, tolerance)#Calculating the minima 
            current = current + theta * e[:, i]                                     #along the dimension

        for i in range(dimension - 1):# x,y,z--> y,z,v1 and so on, this loop does the droping of direction
            e[:, i] = e[:, i + 1]
        e[:, dimension - 1] = current - x

        x1 = x
        theta = helper_function(function, e[:, dimension - 1], current, gda, gdb, tolerance)
        x = current + theta * e[:, dimension - 1]
        minlist.append(x)

       
    fx = function(x)

    return x, fx, num_iterations,e,np.array(minlist)

# %%
b = np.array([0,0,0]).T
ans_powell_nice=powell(func_ND, golden_ratio, b, 1e-8)

# %%
ans_powell_nice
# Out:
# (array([0.52731591, 0.26015149, 0.23809492]),
#  0.5000046175144227,
#  3,
#  array([[5.27315901e-01, 1.42422174e-09, 1.42422174e-09],
#         [2.60151484e-01, 3.40352935e-09, 7.02640279e-10],
#         [2.38094878e-01, 3.32972759e-08, 3.34395703e-09]]),
#  array([[0.5273159 , 0.26015148, 0.23809488],
#         [0.5273159 , 0.26015149, 0.23809491],
#         [0.52731591, 0.26015149, 0.23809492]]))

# %%
ans_powell_nice[3]# Conjugate direction
# Out:
# array([[5.27315901e-01, 1.42422174e-09, 1.42422174e-09],
#        [2.60151484e-01, 3.40352935e-09, 7.02640279e-10],
#        [2.38094878e-01, 3.32972759e-08, 3.34395703e-09]])

# %%
def eigenvalues_eigenvector(mat):
    mat = np.array(mat, dtype=float)
    eigen_values,eigen_vector=np.linalg.eig(mat)
    
    sorted_eigen_values=np.sort(eigen_values)[::-1]
    j=np.argsort(eigen_values)[::-1]
    
    sorted_eigen_vector=np.zeros((3,3),dtype='float')
    for i in range(sorted_eigen_values.shape[0]):
        sorted_eigen_vector[:,i]=eigen_vector[:,j[i]]
        
    return sorted_eigen_values,sorted_eigen_vector

# %% [markdown]
#  ### $Minimizing$ $along$ $Cordinate$ $directions$

# %%
def f(x):
    val=(x[0]-0.5)**2+(0.5*x[0]+x[1]-0.5)**2+(0.25*x[0]+0.5*x[1]+x[2]-0.5)**2
    return 1.5-sp.jv(0,val)

# %%
pos=np.array([0,0,0],dtype=np.float64)
deltax=np.array([1e-4,0,0])
deltay=np.array([0,1e-4,0])
deltaz=np.array([0,0,1e-4])
dirs=[deltax,deltay,deltaz]
for i in range(10):
    prev=f(pos)
    if f(pos)>f(pos+dirs[0]):
        while f(pos)>f(pos+dirs[0]):
            pos=pos+dirs[0]
    elif(f(pos)>f(pos-dirs[0])):
        while f(pos)>f(pos-dirs[0]):
            pos=pos-dirs[0]
    if f(pos)>f(pos+dirs[1]):
        while f(pos)>f(pos+dirs[1]):
            pos=pos+dirs[1]
    elif f(pos)>f(pos-dirs[1]):
        while f(pos)>f(pos-dirs[1]):
            pos=pos-dirs[1]
    if f(pos)>f(pos+dirs[2]):
        while f(pos)>f(pos+dirs[2]):
            pos=pos+dirs[2]
    elif f(pos)>f(pos-dirs[2]):
        while f(pos)>f(pos-dirs[2]):
            pos=pos-dirs[2]
    print (pos, f(pos))
    if abs(prev-f(pos))<1e-10:
        break
# Out:
# [0.6667 0.2666 0.2   ] 0.5003567793641424
# [0.5016 0.2692 0.24  ] 0.500000040513638
# [0.4928 0.2576 0.248 ] 0.5000000011505664
# [0.4968 0.2524 0.2496] 0.5000000000295935
# [0.4989 0.2507 0.2499] 0.5000000000003801

# %% [markdown]
# ### $Conjugate$ $gradient$

# %%
def step_length(f, g, xk, alpha, pk, c2):
    return interpolation(f, g,
                       lambda alpha: f(xk + alpha * pk),
                       lambda alpha: np.dot(g(xk + alpha * pk), pk),
                       alpha, c2,
                       lambda f, g, alpha, c2: strong_wolfe(f, g, xk, alpha, pk, c2))

# %%
def wolfe(f, g, xk, alpha, pk):
    c1 = 1e-4
    return f(xk + alpha * pk) <= f(xk) + c1 * alpha * np.dot(g(xk), pk)


def strong_wolfe(f, g, xk, alpha, pk, c2):
  # typically, c2 = 0.9 when using Newton or quasi-Newton's method.
  #            c2 = 0.1 when using non-linear conjugate gradient method.
      return wolfe(f, g, xk, alpha, pk) and abs(
           np.dot(g(xk + alpha * pk), pk)) <= c2 * abs(np.dot(g(xk), pk))

# %%
def interpolation(f, g, f_alpha, g_alpha, alpha, c2, strong_wolfe_alpha, iters=20):
  # referred implementation here:
  # https://github.com/tamland/non-linear-optimization
    l = 0.0
    h = 1.0
    for i in range(iters):
        if strong_wolfe_alpha(f, g, alpha, c2):
            return alpha

        half = (l + h) / 2
        alpha = - g_alpha(l) * (h**2) / (2 * (f_alpha(h) - f_alpha(l) - g_alpha(l) * h))
        if alpha < l or alpha > h:
            alpha = half
        if g_alpha(alpha) > 0:
            h = alpha
        elif g_alpha(alpha) <= 0:
            l = alpha
    return alpha

# %%
def conjugate_gradient(f, g, x0, iterations, error):
    
    xk = x0
    c2 = 0.1

    fk = f(xk)
    gk = g(xk)
    pk = -1*gk
    count=0
    plist=[pk]
    glist=[gk]

    for i in range(iterations):
        alpha = step_length(f, g, xk, 1.0, pk, c2)
        xk1 = xk + alpha * pk
        gk1 = g(xk1)
        beta_k1 = np.dot(gk1, gk1) / np.dot(gk, gk)
        pk1 = -gk1 + beta_k1 * pk #conjugate directions
        count=count+1
        plist.append(pk1)
        glist.append(gk1)
        if np.linalg.norm(xk1 - xk) < error:
            xk = xk1
            break

        xk = xk1
        gk = gk1
        pk = pk1

    return xk, count, np.array(plist),np.array(glist)

# %%
def gradxFunc_ND(x):
    val=(x[0]-0.5)**2+(0.5*x[0]+x[1]-0.5)**2+(0.25*x[0]+0.5*x[1]+x[2]-0.5)**2                     
    return sp.jv(1,val)*(2*(x[0]-0.5)+(0.5*x[0]+x[1]-0.5)+0.5*(0.25*x[0]+0.5*x[1]+x[2]-0.5))

# %%
def gradyFunc_ND(x):
    val=(x[0]-0.5)**2+(0.5*x[0]+x[1]-0.5)**2+(0.25*x[0]+0.5*x[1]+x[2]-0.5)**2                                         
    return sp.jv(1,val)*((x[0]+2*x[1]-1)+0.25*x[0]+0.5*x[1]+x[2]-0.5)

# %%
def gradzFunc_ND(x):
    val=(x[0]-0.5)**2+(0.5*x[0]+x[1]-0.5)**2+(0.25*x[0]+0.5*x[1]+x[2]-0.5)**2                                         
    return sp.jv(1,val)*(0.5*x[0]+x[1]+2*x[2]-1)

# %%
def grad_vec(x):
    grad=np.array([gradxFunc_ND(x),gradyFunc_ND(x),gradzFunc_ND(x)])
    return grad

# %%
start=[0,0,0]
ans1=conjugate_gradient(func_ND,grad_vec,start,500,1e-10)

# %%
ans1
# Out:
# (array([0.4969776 , 0.25535728, 0.24604867]),
#  500,
#  array([[ 6.11176304e-01,  5.23865403e-01,  3.49243602e-01],
#         [ 1.60104276e-02,  8.75843990e-03,  7.12612610e-03],
#         [ 1.90555481e-02,  9.92642971e-03,  8.31452882e-03],
#         ...,
#         [ 6.19875384e-06, -1.03966515e-05,  7.29450682e-06],
#         [ 6.17279110e-06, -1.03569707e-05,  7.26782422e-06],
#         [ 6.14699231e-06, -1.03175148e-05,  7.24128710e-06]]),
#  array([[-6.11176304e-01, -5.23865403e-01, -3.49243602e-01],
#         [-1.57184004e-02, -8.50813084e-03, -6.95925339e-03],
#         [-1.12029428e-02, -5.63069364e-03, -4.81939074e-03],
#         ...,
#         [-4.55897058e-08,  8.03336836e-08, -5.75210156e-08],
#         [-4.53168855e-08,  7.98705490e-08, -5.71971092e-08],
#         [-4.50462711e-08,  7.94109400e-08, -5.68756397e-08]]))

# %%
lasth=ans1[2][-1,:]
lastg=ans1[3][-1,:]

# %%
np.dot(lasth,lastg)
# Out:
# -1.5080754666307412e-12

# %%
ans1[0]# Fletcher-Reeves
# Out:
# array([0.4969776 , 0.25535728, 0.24604867])

# %%
ans1[0]#Polak and Ribiere
# Out:
# array([0.46998097, 0.28500678, 0.23331086])

# %% [markdown]
#  #### Fletcher-reeves is more accurate compared to Polak-Ribiere

# %% [markdown]
# ### $Gradient$ $Descent$

# %%
learning_rate=3
pos=np.array([0,0,0],dtype=np.float64)
for i in range(1000):
    prev=func_ND(pos)                                                        
    delx=gradxFunc_ND(pos)
    dely=gradyFunc_ND(pos)
    delz=gradzFunc_ND(pos)
    pos[0]-=learning_rate*delx
    pos[1]-=learning_rate*dely
    pos[2]-=learning_rate*delz
    print (pos, func_ND(pos),i+1)
    if abs(prev-func_ND(pos))<1e-10:
        break
    else:
        print (abs(prev-func_ND(pos)))
# Out:
# [1.83352891 1.57159621 1.04773081] 1.2845434652665406 1
# 0.2683078936311718
# [-2.35758622 -2.78354228 -1.65794379] 1.4150170133850573 2
# 0.13047354811851664
# [-0.45678944 -0.75598725 -0.37312809] 1.2027129617508001 3
# 0.21230405163425714
# [-4.44294889 -4.98974203 -3.0405556 ] 1.5480876430420474 4
# 0.34537468129124727
# [-1.00493844 -1.32463326 -0.71950144] 1.577711199589674 5
# 0.029623556547626606
# [-4.89788765 -5.45088074 -3.31303884] 1.4866427653041245 6
# 0.09106843428554945
# [-1.11668622 -1.4262746  -0.76910453] 1.3561154624444005 7
# 0.13052730285972403
# [1.2810071  1.10513813 0.81431372] 1.7149602647717688 8
# 0.35884480232736826
# [ 0.18253102 -0.08286217  0.04750786] 0.6485114861454012 9
# 1.0664487786263677
# [1.24336374 1.04143449 0.75168835] 1.8519312989246406 10
# 1.2034198127792393
# [-1.71625316 -2.12035665 -1.25741569] 1.376818702948539 11
# 0.47511259597610156
# [2.61972478 2.52000531 1.69558717] 1.632564131382178 12
# 0.2557454284336389
# [5.23921446 5.32485685 3.48152794] 1.4532861283544733 13
# 0.17927800302770458
# [6.15012296 6.30019565 4.10253867] 1.4497633408553783 14
# 0.0035227874990950703
# [4.32596714 4.34702481 2.85893736] 1.5117475045076452 15
# 0.06198416365226689
# [5.13689357 5.21531785 3.41179637] 1.4500609457281142 16
# 0.061686558779531
# [2.39990604 2.28473098 1.5458493 ] 1.6271651409741401 17
# 0.17710419524602594
# [-0.31874774 -0.62637799 -0.30780157] 1.5781476203074378 18
# 0.049017520666702286
# [-0.03301694 -0.32048838 -0.11307351] 1.413555907215419 19
# 0.16459171309201892
# [3.88561028 3.87446161 2.55731341] 1.5162553168719077 20
# 0.10269940965648883
# [0.8136609  0.58557475 0.46347568] 0.6452020113006182 21
# 0.8710533055712896
# [-0.26202569 -0.56577089 -0.26930761] 1.799817875337257 22
# 1.1546158640366389
# [2.06134245 1.92165279 1.31427586] 1.3317947888070094 23
# 0.4680230865302475
# [0.47457624 0.22276409 0.23264902] 0.5000065185462688 24
# 0.8317882702607406
# [0.47517312 0.22340329 0.23305608] 0.5000059276798121 25
# 5.908664566511845e-07
# [0.47572894 0.22399853 0.23343516] 0.5000054144556008 26
# 5.132242113514707e-07
# [0.47624827 0.2245547  0.23378934] 0.5000049657467833 27
# 4.48708817435417e-07
# [0.47673498 0.22507593 0.23412128] 0.5000045711026753 28
# 3.946441080593388e-07
# [0.47719238 0.22556578 0.23443324] 0.5000042221170139 29
# 3.489856613692055e-07
# [0.47762334 0.22602731 0.23472716] 0.5000039119641927 30
# 3.1015282120350207e-07
# [0.47803034 0.22646318 0.23500474] 0.5000036350541549 31
# 2.7691003778862466e-07
# [0.47841553 0.2268757  0.23526745] 0.5000033867723813 32
# 2.482817735849352e-07
# [0.47878083 0.22726691 0.23551659] 0.500003163281747 33
# 2.2349063433235727e-07
# [0.47912789 0.22763859 0.2357533 ] 0.5000029613699307 34
# 2.0191181626660892e-07
# [0.4794582  0.22799234 0.23597859] 0.500002778330763 35
# 1.830391677115628e-07
# [0.47977308 0.22832957 0.23619335] 0.5000026118711268 36
# 1.6645963618611148e-07
# [0.48007371 0.22865152 0.23639839] 0.5000024600372995 37
# 1.5183382728878314e-07
# [0.48036113 0.22895934 0.23659443] 0.500002321156215 38
# 1.3888108452153602e-07
# [0.4806363  0.22925404 0.23678211] 0.5000021937882866 39
# 1.2736792842638067e-07
# [0.48090007 0.22953652 0.23696201] 0.5000020766892507 40
# 1.1709903591228255e-07
# [0.4811532  0.22980762 0.23713466] 0.500001968779113 41
# 1.0791013771438429e-07
# [0.48139641 0.23006809 0.23730054] 0.5000018691167178 42
# 9.966239511438602e-08
# [0.48163033 0.2303186  0.23746009] 0.5000017768788076 43
# 9.22379101986337e-08
# [0.48185553 0.23055979 0.23761369] 0.5000016913426844 44
# 8.553612329542659e-08
# [0.48207256 0.23079222 0.23776172] 0.5000016118717814 45
# 7.947090296944737e-08
# [0.48228189 0.23101641 0.2379045 ] 0.5000015379036 46
# 7.396818135774197e-08
# [0.48248398 0.23123284 0.23804234] 0.5000014689395765 47
# 6.89640234918798e-08
# [0.48267923 0.23144196 0.23817552] 0.5000014045365331 48
# 6.440304345378678e-08
# [0.48286803 0.23164415 0.23830429] 0.5000013442994369 49
# 6.023709619995543e-08
# [0.48305072 0.23183982 0.2384289 ] 0.500001287875242 50
# 5.642419487195127e-08
# [0.48322763 0.23202929 0.23854957] 0.500001234947633 51
# 5.2927608962249906e-08
# [0.48339906 0.23221289 0.2386665 ] 0.5000011852325222 52
# 4.971511080587021e-08
# [0.48356529 0.23239092 0.23877989] 0.5000011384741788 53
# 4.675834341938412e-08
# [0.48372658 0.23256366 0.2388899 ] 0.5000010944418917 54
# 4.4032287149775584e-08
# [0.48388317 0.23273136 0.23899671] 0.5000010529270811 55
# 4.1514810589227125e-08
# [0.48403528 0.23289427 0.23910046] 0.5000010137407942 56
# 3.918628688204251e-08
# [0.48418312 0.23305262 0.23920131] 0.5000009767115251 57
# 3.702926909543436e-08
# [0.4843269  0.2332066  0.23929938] 0.5000009416833121 58
# 3.5028212996834895e-08
# [0.4844668  0.23335643 0.2393948 ] 0.5000009085140745 59
# 3.3169237578789534e-08
# [0.48460298 0.23350228 0.23948769] 0.5000008770741525 60
# 3.1439921999165676e-08
# [0.48473561 0.23364433 0.23957816] 0.5000008472450239 61
# 2.9829128611602584e-08
# [0.48486485 0.23378274 0.23966632] 0.5000008189181735 62
# 2.83268504208678e-08
# [0.48499083 0.23391767 0.23975225] 0.5000007919940941 63
# 2.692407941040642e-08
# [0.48511369 0.23404926 0.23983606] 0.5000007663814019 64
# 2.5612692189369568e-08
# [0.48523357 0.23417764 0.23991783] 0.5000007419960523 65
# 2.4385349628452957e-08
# [0.48535057 0.23430295 0.23999763] 0.500000718760642 66
# 2.3235410262500977e-08
# [0.48546481 0.23442531 0.24007556] 0.5000006966037885 67
# 2.215685346307339e-08
# [0.4855764  0.23454482 0.24015168] 0.5000006754595755 68
# 2.114421304710845e-08
# [0.48568544 0.23466161 0.24022606] 0.5000006552670566 69
# 2.0192518879191823e-08
# [0.48579203 0.23477577 0.24029877] 0.5000006359698128 70
# 1.929724380289599e-08
# [0.48589625 0.23488739 0.24036986] 0.5000006175155532 71
# 1.845425956492619e-08
# [0.4859982  0.23499658 0.24043941] 0.5000005998557576 72
# 1.7659795625846186e-08
# [0.48609796 0.23510342 0.24050745] 0.500000582945354 73
# 1.6910403632941495e-08
# [0.48619559 0.235208   0.24057405] 0.5000005667424283 74
# 1.6202925667840873e-08
# [0.48629119 0.23531038 0.24063926] 0.5000005512079623 75
# 1.5534466046851492e-08
# [0.48638481 0.23541066 0.24070313] 0.5000005363055958 76
# 1.490236645196319e-08
# [0.48647653 0.23550889 0.2407657 ] 0.5000005220014131 77
# 1.4304182727187253e-08
# [0.48656641 0.23560516 0.24082701] 0.5000005082637468 78
# 1.373766633783191e-08
# [0.48665451 0.23569952 0.2408871 ] 0.5000004950630016 79
# 1.3200745163644001e-08
# [0.48674089 0.23579203 0.24094603] 0.5000004823714935 80
# 1.2691508066708934e-08
# [0.48682561 0.23588276 0.24100381] 0.5000004701633034 81
# 1.2208190125484464e-08
# [0.48690871 0.23597176 0.2410605 ] 0.5000004584141433 82
# 1.1749160089280508e-08
# [0.48699024 0.23605909 0.24111612] 0.5000004471012346 83
# 1.1312908720917392e-08
# [0.48707027 0.2361448  0.24117071] 0.5000004362031969 84
# 1.08980376944956e-08
# [0.48714882 0.23622894 0.2412243 ] 0.5000004256999458 85
# 1.0503251046678486e-08
# [0.48722596 0.23631156 0.24127692] 0.5000004155726002 86
# 1.0127345628774265e-08
# [0.48730171 0.23639269 0.2413286 ] 0.5000004058033959 87
# 9.769204334375559e-09
# [0.48737613 0.23647239 0.24137936] 0.5000003963756077 88
# 9.427788216775923e-09
# [0.48744924 0.2365507  0.24142923] 0.5000003872734772 89
# 9.102130493765515e-09
# [0.4875211  0.23662766 0.24147825] 0.5000003784821461 90
# 8.79133110753827e-09
# [0.48759172 0.2367033  0.24152643] 0.5000003699875954 91
# 8.494550618465269e-09
# [0.48766116 0.23677767 0.24157379] 0.5000003617765888 92
# 8.211006652381059e-09
# [0.48772943 0.2368508  0.24162037] 0.5000003538366212 93
# 7.939967572312412e-09
# [0.48779658 0.23692272 0.24166618] 0.5000003461558704 94
# 7.680750813143788e-09
# [0.48786263 0.23699346 0.24171124] 0.5000003387231525 95
# 7.432717885613727e-09
# [0.48792762 0.23706307 0.24175557] 0.5000003315278817 96
# 7.195270823601163e-09
# [0.48799157 0.23713156 0.24179919] 0.5000003245600313 97
# 6.967850407768594e-09
# [0.4880545  0.23719897 0.24184213] 0.5000003178100996 98
# 6.7499317246699775e-09
# [0.48811646 0.23726533 0.24188439] 0.5000003112690765 99
# 6.541023056527706e-09
# [0.48817745 0.23733065 0.241926  ] 0.5000003049284134 100
# 6.3406631056750484e-09
# [0.48823751 0.23739498 0.24196697] 0.5000002987799954 101
# 6.148417996953981e-09
# [0.48829666 0.23745834 0.24200733] 0.5000002928161148 102
# 5.963880611581374e-09
# [0.48835493 0.23752074 0.24204707] 0.5000002870294467 103
# 5.786668144658336e-09
# [0.48841232 0.23758222 0.24208623] 0.500000281413027 104
# 5.6164196626795615e-09
# [0.48846888 0.23764279 0.24212481] 0.5000002759602303 105
# 5.452796658644843e-09
# [0.48852461 0.23770248 0.24216283] 0.5000002706647512 106
# 5.295479166278483e-09
# [0.48857953 0.23776131 0.2422003 ] 0.5000002655205855 107
# 5.144165649006993e-09
# [0.48863367 0.2378193  0.24223723] 0.5000002605220132 108
# 4.99857233382528e-09
# [0.48868705 0.23787647 0.24227364] 0.5000002556635822 109
# 4.858430990850593e-09
# [0.48873968 0.23793283 0.24230955] 0.5000002509400935 110
# 4.723488711277923e-09
# [0.48879157 0.23798842 0.24234495] 0.5000002463465877 111
# 4.593505797956254e-09
# [0.48884275 0.23804324 0.24237987] 0.5000002418783311 112
# 4.46825654254468e-09
# [0.48889324 0.23809731 0.24241431] 0.5000002375308041 113
# 4.347527005066354e-09
# [0.48894304 0.23815065 0.24244828] 0.5000002332996891 114
# 4.231115013908493e-09
# [0.48899218 0.23820328 0.2424818 ] 0.5000002291808604 115
# 4.118828722532442e-09
# [0.48904066 0.23825521 0.24251488] 0.5000002251703732 116
# 4.010487164585186e-09
# [0.48908851 0.23830646 0.24254752] 0.5000002212644551 117
# 3.905918144475606e-09
# [0.48913573 0.23835704 0.24257974] 0.5000002174594965 118
# 3.804958570441386e-09
# [0.48918234 0.23840697 0.24261154] 0.5000002137520423 119
# 3.7074542325044035e-09
# [0.48922836 0.23845625 0.24264293] 0.5000002101387845 120
# 3.613257804069292e-09
# [0.48927379 0.23850491 0.24267392] 0.5000002066165538 121
# 3.522230729302578e-09
# [0.48931865 0.23855296 0.24270452] 0.5000002031823136 122
# 3.4342401145082135e-09
# [0.48936295 0.23860041 0.24273475] 0.5000001998331532 123
# 3.349160393462114e-09
# [0.48940669 0.23864727 0.24276459] 0.500000196566281 124
# 3.2668722171891318e-09
# [0.48944991 0.23869355 0.24279407] 0.5000001933790195 125
# 3.187261565784638e-09
# [0.48949259 0.23873927 0.24282319] 0.5000001902687987 126
# 3.1102207476152444e-09
# [0.48953476 0.23878444 0.24285196] 0.5000001872331524 127
# 3.0356462898950554e-09
# [0.48957643 0.23882907 0.24288039] 0.500000184269712 128
# 2.9634403819756017e-09
# [0.4896176  0.23887316 0.24290847] 0.5000001813762023 129
# 2.8935097651228148e-09
# [0.48965828 0.23891674 0.24293623] 0.500000178550437 130
# 2.8257652884278173e-09
# [0.48969849 0.2389598  0.24296366] 0.500000175790315 131
# 2.7601220198292253e-09
# [0.48973823 0.23900237 0.24299077] 0.500000173093816 132
# 2.696499024068544e-09
# [0.48977751 0.23904444 0.24301757] 0.5000001704589967 133
# 2.6348192516678637e-09
# [0.48981634 0.23908604 0.24304407] 0.5000001678839877 134
# 2.57500898381835e-09
# [0.48985474 0.23912716 0.24307026] 0.5000001653669899 135
# 2.516997832380241e-09
# [0.4898927  0.23916782 0.24309616] 0.5000001629062716 136
# 2.4607182957936402e-09
# [0.48993023 0.23920802 0.24312176] 0.500000160500165 137
# 2.4061065362346312e-09
# [0.48996735 0.23924778 0.24314709] 0.5000001581470641 138
# 2.3531009363253474e-09
# [0.49000406 0.2392871  0.24317213] 0.500000155845421 139
# 2.3016430983346936e-09
# [0.49004037 0.23932599 0.2431969 ] 0.5000001535937445 140
# 2.2516765119107163e-09
# [0.49007628 0.23936446 0.24322141] 0.5000001513905967 141
# 2.203147775325931e-09
# [0.49011181 0.23940252 0.24324565] 0.5000001492345915 142
# 2.1560052632096927e-09
# [0.49014696 0.23944016 0.24326963] 0.5000001471243913 143
# 2.110200125748918e-09
# [0.49018173 0.23947741 0.24329335] 0.5000001450587066 144
# 2.06568473437585e-09
# [0.49021614 0.23951427 0.24331682] 0.5000001430362921 145
# 2.0224144581248993e-09
# [0.49025019 0.23955073 0.24334005] 0.5000001410559465 146
# 1.980345665231198e-09
# [0.49028388 0.23958682 0.24336304] 0.5000001391165094 147
# 1.93943705539823e-09
# [0.49031723 0.23962254 0.24338579] 0.5000001372168605 148
# 1.8996488826417135e-09
# [0.49035023 0.23965789 0.24340831] 0.5000001353559177 149
# 1.8609428442672993e-09
# [0.4903829  0.23969288 0.24343059] 0.500000133532635 150
# 1.8232827470043844e-09
# [0.49041524 0.23972752 0.24345266] 0.5000001317460019 151
# 1.786633063716181e-09
# [0.49044725 0.23976181 0.2434745 ] 0.5000001299950417 152
# 1.7509601546450426e-09
# [0.49047894 0.23979575 0.24349612] 0.5000001282788099 153
# 1.7162318233232554e-09
# [0.49051032 0.23982936 0.24351753] 0.5000001265963928 154
# 1.6824170945284322e-09
# [0.49054139 0.23986264 0.24353872] 0.5000001249469072 155
# 1.6494856591720009e-09
# [0.49057215 0.23989559 0.24355971] 0.500000123329498 156
# 1.6174092065668333e-09
# [0.49060262 0.23992823 0.2435805 ] 0.500000121743338 157
# 1.586159981137314e-09
# [0.49063279 0.23996054 0.24360108] 0.5000001201876263 158
# 1.5557116705977592e-09
# [0.49066267 0.23999255 0.24362147] 0.5000001186615879 159
# 1.5260384067516952e-09
# [0.49069227 0.24002425 0.24364166] 0.5000001171644719 160
# 1.4971159867371853e-09
# [0.49072158 0.24005565 0.24366167] 0.5000001156955514 161
# 1.4689205407591999e-09
# [0.49075063 0.24008676 0.24368148] 0.5000001142541219 162
# 1.4414294202680367e-09
# [0.49077939 0.24011757 0.24370111] 0.5000001128395009 163
# 1.414621086937018e-09
# [0.4908079  0.2401481  0.24372055] 0.500000111451027 164
# 1.3884738914171635e-09
# [0.49083613 0.24017835 0.24373982] 0.5000001100880591 165
# 1.36296784969403e-09
# [0.49086411 0.24020832 0.24375891] 0.5000001087499755 166
# 1.3380836438869892e-09
# [0.49089184 0.24023801 0.24377782] 0.5000001074361736 167
# 1.31380184509311e-09
# [0.49091931 0.24026744 0.24379657] 0.5000001061460689 168
# 1.2901046897439983e-09
# [0.49094653 0.2402966  0.24381514] 0.500000104879094 169
# 1.2669749693827725e-09
# [0.49097351 0.2403255  0.24383355] 0.5000001036346989 170
# 1.2443950314633412e-09
# [0.49100025 0.24035414 0.24385179] 0.5000001024123497 171
# 1.222349221841057e-09
# [0.49102675 0.24038253 0.24386987] 0.500000101211528 172
# 1.2008216643266678e-09
# [0.49105302 0.24041067 0.2438878 ] 0.5000001000317309 173
# 1.1797971488647363e-09
# [0.49107906 0.24043856 0.24390556] 0.5000000988724698 174
# 1.1592611315336399e-09
# [0.49110488 0.24046621 0.24392317] 0.5000000977332704 175
# 1.1391994014786633e-09
# [0.49113047 0.24049362 0.24394063] 0.5000000966136721 176
# 1.1195983029566037e-09
# [0.49115583 0.24052079 0.24395794] 0.5000000955132271 177
# 1.1004449573803754e-09
# [0.49118099 0.24054773 0.2439751 ] 0.5000000944315008 178
# 1.0817262641182879e-09
# [0.49120593 0.24057445 0.24399212] 0.5000000933680705 179
# 1.0634303437839776e-09
# [0.49123065 0.24060093 0.24400899] 0.5000000923225256 180
# 1.0455448729018713e-09
# [0.49125517 0.2406272  0.24402572] 0.5000000912944667 181
# 1.0280589712863275e-09
# [0.49127949 0.24065324 0.24404231] 0.5000000902835059 182
# 1.0109607595509829e-09
# [0.4913036  0.24067907 0.24405876] 0.5000000892892655 183
# 9.942403567109181e-10
# [0.49132751 0.24070468 0.24407508] 0.5000000883113787 184
# 9.77886882580492e-10
# [0.49135123 0.24073009 0.24409126] 0.5000000873494884 185
# 9.618902341301805e-10
# [0.49137475 0.24075528 0.24410731] 0.5000000864032471 186
# 9.462413075311815e-10
# [0.49139808 0.24078027 0.24412323] 0.5000000854723172 187
# 9.309298887316686e-10
# [0.49142123 0.24080506 0.24413902] 0.5000000845563695 188
# 9.159477620812595e-10
# [0.49144418 0.24082965 0.24415468] 0.5000000836550839 189
# 9.012856017065474e-10
# [0.49146696 0.24085405 0.24417022] 0.5000000827681491 190
# 8.869347478679401e-10
# [0.49148955 0.24087824 0.24418563] 0.5000000818952616 191
# 8.728875400265679e-10
# [0.49151196 0.24090225 0.24420092] 0.5000000810361259 192
# 8.591356515097459e-10
# [0.4915342  0.24092607 0.24421609] 0.5000000801904547 193
# 8.456711997339994e-10
# [0.49155626 0.2409497  0.24423115] 0.5000000793579676 194
# 8.324870792719707e-10
# [0.49157815 0.24097315 0.24424608] 0.5000000785383919 195
# 8.195757406070925e-10
# [0.49159987 0.24099641 0.2442609 ] 0.5000000777314616 196
# 8.06930300356612e-10
# [0.49162142 0.2410195  0.24427561] 0.5000000769369178 197
# 7.94543764115474e-10
# [0.49164281 0.24104241 0.2442902 ] 0.5000000761545079 198
# 7.824099146347407e-10
# [0.49166403 0.24106514 0.24430468] 0.5000000753839858 199
# 7.705220905762644e-10
# [0.49168509 0.2410877  0.24431905] 0.500000074625112 200
# 7.588738526465022e-10
# [0.491706   0.24111009 0.24433332] 0.5000000738776524 201
# 7.474595387080285e-10
# [0.49172674 0.24113232 0.24434747] 0.5000000731413792 202
# 7.362732645788128e-10
# [0.49174733 0.24115437 0.24436152] 0.5000000724160698 203
# 7.253093681214295e-10
# [0.49176777 0.24117627 0.24437546] 0.5000000717015077 204
# 7.145620761761506e-10
# [0.49178806 0.241198   0.24438931] 0.5000000709974816 205
# 7.040261706947604e-10
# [0.4918082  0.24121957 0.24440305] 0.5000000703037847 206
# 6.936968777182528e-10
# [0.49182818 0.24124098 0.24441668] 0.5000000696202161 207
# 6.835685351092025e-10
# [0.49184803 0.24126223 0.24443022] 0.5000000689465793 208
# 6.736368129978132e-10
# [0.49186773 0.24128333 0.24444366] 0.5000000682826828 209
# 6.638964933358693e-10
# [0.49188728 0.24130428 0.24445701] 0.5000000676283394 210
# 6.543434682981797e-10
# [0.4919067  0.24132508 0.24447026] 0.5000000669833665 211
# 6.44972852903436e-10
# [0.49192598 0.24134573 0.24448341] 0.5000000663475861 212
# 6.357804283041446e-10
# [0.49194512 0.24136623 0.24449647] 0.500000065720824 213
# 6.267620866751145e-10
# [0.49196412 0.24138659 0.24450944] 0.5000000651029105 214
# 6.179134981465495e-10
# [0.49198299 0.2414068  0.24452231] 0.5000000644936795 215
# 6.092309989824685e-10
# [0.49200173 0.24142687 0.2445351 ] 0.500000063892969 216
# 6.007104813576802e-10
# [0.49202033 0.2414468  0.24454779] 0.5000000633006209 217
# 5.923481705139011e-10
# [0.49203881 0.24146659 0.2445604 ] 0.5000000627164802 218
# 5.841406247597547e-10
# [0.49205716 0.24148625 0.24457292] 0.5000000621403962 219
# 5.760840693369573e-10
# [0.49207538 0.24150576 0.24458535] 0.5000000615722211 220
# 5.681750625541326e-10
# [0.49209348 0.24152515 0.2445977 ] 0.5000000610118109 221
# 5.604101627199043e-10
# [0.49211145 0.2415444  0.24460996] 0.5000000604590243 222
# 5.527865942767107e-10
# [0.4921293  0.24156352 0.24462214] 0.5000000599137239 223
# 5.453004714439658e-10
# [0.49214703 0.24158252 0.24463424] 0.5000000593757747 224
# 5.379491296864103e-10
# [0.49216464 0.24160138 0.24464626] 0.5000000588450454 225
# 5.307293493572729e-10
# [0.49218214 0.24162012 0.24465819] 0.5000000583214069 226
# 5.236384659212945e-10
# [0.49219951 0.24163873 0.24467005] 0.5000000578047337 227
# 5.166732597317036e-10
# [0.49221677 0.24165722 0.24468183] 0.5000000572949026 228
# 5.098310662532413e-10
# [0.49223392 0.24167559 0.24469353] 0.500000056791793 229
# 5.031095540175556e-10
# [0.49225095 0.24169383 0.24470515] 0.5000000562952875 230
# 4.965055033778754e-10
# [0.49226787 0.24171196 0.24471669] 0.5000000558052707 231
# 4.900168049104536e-10
# [0.49228468 0.24172996 0.24472816] 0.50000005532163 232
# 4.836406830577289e-10
# [0.49230139 0.24174785 0.24473956] 0.5000000548442554 233
# 4.77374695329047e-10
# [0.49231798 0.24176563 0.24475088] 0.5000000543730387 234
# 4.712166212783586e-10
# [0.49233446 0.24178329 0.24476213] 0.5000000539078746 235
# 4.651641294373121e-10
# [0.49235084 0.24180083 0.24477331] 0.5000000534486598 236
# 4.592147773152533e-10
# [0.49236712 0.24181827 0.24478441] 0.500000052995293 237
# 4.5336678855534274e-10
# [0.49238329 0.24183559 0.24479545] 0.5000000525476754 238
# 4.4761760964462383e-10
# [0.49239936 0.2418528  0.24480641] 0.5000000521057101 239
# 4.419653532039547e-10
# [0.49241533 0.24186991 0.24481731] 0.5000000516693023 240
# 4.364077987872861e-10
# [0.4924312  0.24188691 0.24482814] 0.5000000512383591 241
# 4.309431700377786e-10
# [0.49244697 0.2419038  0.2448389 ] 0.5000000508127896 242
# 4.255694685539879e-10
# [0.49246264 0.24192058 0.24484959] 0.5000000503925048 243
# 4.2028480695677217e-10
# [0.49247821 0.24193726 0.24486021] 0.5000000499774175 244
# 4.150872978669895e-10
# [0.49249368 0.24195384 0.24487077] 0.5000000495674423 245
# 4.0997527595010297e-10
# [0.49250907 0.24197032 0.24488127] 0.5000000491624954 246
# 4.049468538269707e-10
# [0.49252435 0.24198669 0.2448917 ] 0.500000048762495 247
# 4.000003661630558e-10
# [0.49253955 0.24200297 0.24490207] 0.5000000483673607 248
# 3.951343696684262e-10
# [0.49255465 0.24201914 0.24491237] 0.5000000479770139 249
# 3.9034675491933513e-10
# [0.49256966 0.24203522 0.24492261] 0.5000000475913775 250
# 3.85636411692758e-10
# [0.49258458 0.2420512  0.24493279] 0.500000047210376 251
# 3.8100145260955287e-10
# [0.49259941 0.24206709 0.24494291] 0.5000000468339353 252
# 3.764407674466952e-10
# [0.49261415 0.24208288 0.24495297] 0.5000000464619829 253
# 3.719523578027406e-10
# [0.4926288  0.24209857 0.24496297] 0.5000000460944477 254
# 3.6753522447696696e-10
# [0.49264336 0.24211418 0.24497291] 0.50000004573126 255
# 3.631877021348373e-10
# [0.49265784 0.24212969 0.24498279] 0.5000000453723513 256
# 3.5890868055332703e-10
# [0.49267224 0.24214511 0.24499261] 0.5000000450176548 257
# 3.546964943978992e-10
# [0.49268655 0.24216043 0.24500238] 0.5000000446671048 258
# 3.5055003344552915e-10
# [0.49270077 0.24217567 0.24501208] 0.5000000443206367 259
# 3.4646807645088984e-10
# [0.49271492 0.24219082 0.24502173] 0.5000000439781873 260
# 3.4244940216865416e-10
# [0.49272898 0.24220589 0.24503133] 0.500000043639695 261
# 3.384923452642852e-10
# [0.49274296 0.24222086 0.24504087] 0.5000000433050986 262
# 3.345963506262706e-10
# [0.49275686 0.24223575 0.24505035] 0.5000000429743388 263
# 3.307598639423759e-10
# [0.49277068 0.24225056 0.24505978] 0.500000042647357 264
# 3.269817749895765e-10
# [0.49278442 0.24226528 0.24506916] 0.5000000423240958 265
# 3.2326119558945265e-10
# [0.49279808 0.24227991 0.24507848] 0.5000000420044991 266
# 3.195966824520724e-10
# [0.49281167 0.24229446 0.24508775] 0.5000000416885115 267
# 3.1598756944362094e-10
# [0.49282518 0.24230893 0.24509697] 0.500000041376079 268
# 3.1243252429646873e-10
# [0.49283861 0.24232332 0.24510614] 0.5000000410671483 269
# 3.0893065883219606e-10
# [0.49285197 0.24233763 0.24511525] 0.5000000407616673 270
# 3.0548108487238324e-10
# [0.49286525 0.24235186 0.24512432] 0.5000000404595848 271
# 3.020824701494007e-10
# [0.49287846 0.24236601 0.24513333] 0.5000000401608505 272
# 2.9873425955173616e-10
# [0.4928916  0.24238008 0.24514229] 0.5000000398654151 273
# 2.9543545387866743e-10
# [0.49290466 0.24239408 0.24515121] 0.5000000395732301 274
# 2.921849429071699e-10
# [0.49291765 0.24240799 0.24516007] 0.5000000392842483 275
# 2.8898183845882386e-10
# [0.49293057 0.24242183 0.24516889] 0.5000000389984225 276
# 2.8582580746672193e-10
# [0.49294342 0.2424356  0.24517766] 0.5000000387157072 277
# 2.827152956186296e-10
# [0.4929562  0.24244929 0.24518638] 0.5000000384360573 278
# 2.796498588253371e-10
# [0.49296891 0.2424629  0.24519505] 0.5000000381594287 279
# 2.7662860890842467e-10
# [0.49298156 0.24247645 0.24520368] 0.5000000378857781 280
# 2.736506576894726e-10
# [0.49299413 0.24248991 0.24521226] 0.5000000376150625 281
# 2.707155610792711e-10
# [0.49300664 0.24250331 0.24522079] 0.5000000373472404 282
# 2.67822097832493e-10
# [0.49301908 0.24251664 0.24522928] 0.5000000370822706 283
# 2.649698238599285e-10
# [0.49303145 0.24252989 0.24523772] 0.5000000368201127 284
# 2.621578509831579e-10
# [0.49304376 0.24254308 0.24524612] 0.500000036560727 285
# 2.5938573511297136e-10
# [0.493056   0.24255619 0.24525448] 0.5000000363040746 286
# 2.566523660263442e-10
# [0.49306818 0.24256924 0.24526279] 0.5000000360501171 287
# 2.539575216786716e-10
# [0.49308029 0.24258221 0.24527105] 0.500000035798817 288
# 2.513000918469288e-10
# [0.49309234 0.24259512 0.24527928] 0.5000000355501373 289
# 2.486797434642085e-10
# [0.49310433 0.24260796 0.24528746] 0.5000000353040416 290
# 2.4609569937439346e-10
# [0.49311626 0.24262074 0.24529559] 0.5000000350604943 291
# 2.435472934436689e-10
# [0.49312812 0.24263345 0.24530369] 0.5000000348194602 292
# 2.410340815828249e-10
# [0.49313992 0.24264609 0.24531174] 0.500000034580905 293
# 2.3855517561344186e-10
# [0.49315167 0.24265867 0.24531976] 0.5000000343447947 294
# 2.361103534909148e-10
# [0.49316335 0.24267118 0.24532773] 0.5000000341110958 295
# 2.336988380591265e-10
# [0.49317497 0.24268363 0.24533566] 0.5000000338797759 296
# 2.3131996318426218e-10
# [0.49318653 0.24269602 0.24534355] 0.5000000336508026 297
# 2.2897328477711199e-10
# [0.49319804 0.24270835 0.2453514 ] 0.5000000334241443 298
# 2.266582477261636e-10
# [0.49320949 0.24272061 0.24535921] 0.5000000331997699 299
# 2.243744079422072e-10
# [0.49322088 0.24273281 0.24536698] 0.5000000329776488 300
# 2.2212109929142798e-10
# [0.49323221 0.24274495 0.24537472] 0.5000000327577508 301
# 2.1989798870691857e-10
# [0.49324348 0.24275702 0.24538241] 0.5000000325400464 302
# 2.1770441005486418e-10
# [0.4932547  0.24276904 0.24539007] 0.5000000323245065 303
# 2.1553991924605498e-10
# [0.49326586 0.242781   0.24539768] 0.5000000321111026 304
# 2.1340396116897864e-10
# [0.49327697 0.2427929  0.24540526] 0.5000000318998062 305
# 2.1129631377903024e-10
# [0.49328802 0.24280474 0.24541281] 0.50000003169059 306
# 2.0921619992009255e-10
# [0.49329902 0.24281652 0.24542031] 0.5000000314834268 307
# 2.0716328652525817e-10
# [0.49330997 0.24282824 0.24542778] 0.5000000312782894 308
# 2.0513735154992219e-10
# [0.49332086 0.24283991 0.24543521] 0.5000000310751518 309
# 2.0313761783796735e-10
# [0.4933317  0.24285152 0.24544261] 0.5000000308739879 310
# 2.0116386334478875e-10
# [0.49334248 0.24286307 0.24544997] 0.5000000306747724 311
# 1.9921553295887406e-10
# [0.49335321 0.24287457 0.24545729] 0.5000000304774801 312
# 1.972922936133159e-10
# [0.4933639  0.24288601 0.24546458] 0.5000000302820862 313
# 1.9539392326350935e-10
# [0.49337453 0.2428974  0.24547183] 0.5000000300885665 314
# 1.9351964475333716e-10
# [0.4933851  0.24290873 0.24547905] 0.5000000298968972 315
# 1.9166934706049688e-10
# [0.49339563 0.24292001 0.24548624] 0.5000000297070547 316
# 1.8984247507347618e-10
# [0.49340611 0.24293124 0.24549339] 0.5000000295190157 317
# 1.8803902879227508e-10
# [0.49341654 0.24294241 0.2455005 ] 0.5000000293327577 318
# 1.862580090161714e-10
# [0.49342692 0.24295352 0.24550759] 0.5000000291482579 319
# 1.8449974881207254e-10
# [0.49343725 0.24296459 0.24551464] 0.5000000289654946 320
# 1.827633600015588e-10
# [0.49344753 0.2429756  0.24552165] 0.5000000287844458 321
# 1.810487315623277e-10
# [0.49345776 0.24298657 0.24552863] 0.5000000286050902 322
# 1.7935564144977434e-10
# [0.49346795 0.24299748 0.24553559] 0.5000000284274069 323
# 1.7768331250778147e-10
# [0.49347809 0.24300834 0.2455425 ] 0.5000000282513749 324
# 1.76031966780954e-10
# [0.49348818 0.24301915 0.24554939] 0.5000000280769739 325
# 1.7440104915777965e-10
# [0.49349822 0.24302991 0.24555624] 0.5000000279041839 326
# 1.727900045267461e-10
# [0.49350822 0.24304062 0.24556307] 0.5000000277329849 327
# 1.7119894391015578e-10
# [0.49351817 0.24305128 0.24556986] 0.5000000275633576 328
# 1.696273121964964e-10
# [0.49352808 0.24306189 0.24557662] 0.5000000273952827 329
# 1.6807488734116305e-10
# [0.49353794 0.24307245 0.24558335] 0.5000000272287414 330
# 1.6654133627724832e-10
# [0.49354775 0.24308297 0.24559004] 0.500000027063715 331
# 1.6502632593784483e-10
# [0.49355752 0.24309343 0.24559671] 0.5000000269001853 332
# 1.6352974530065012e-10
# [0.49356725 0.24310385 0.24560335] 0.500000026738134 333
# 1.620512612987568e-10
# [0.49357693 0.24311422 0.24560996] 0.5000000265775437 334
# 1.6059031882065256e-10
# [0.49358657 0.24312455 0.24561654] 0.5000000264183966 335
# 1.5914713991094231e-10
# [0.49359617 0.24313483 0.24562308] 0.5000000262606754 336
# 1.5772116945811376e-10
# [0.49360572 0.24314506 0.2456296 ] 0.5000000261043633 337
# 1.5631207439525951e-10
# [0.49361523 0.24315525 0.24563609] 0.5000000259494435 338
# 1.5491985472237957e-10
# [0.4936247  0.24316539 0.24564255] 0.5000000257958996 339
# 1.5354384430565915e-10
# [0.49363412 0.24317549 0.24564899] 0.5000000256437152 340
# 1.521844872343081e-10
# [0.49364351 0.24318554 0.24565539] 0.5000000254928741 341
# 1.508410063522092e-10
# [0.49365285 0.24319555 0.24566176] 0.500000025343361 342
# 1.4951317961475752e-10
# [0.49366215 0.24320552 0.24566811] 0.50000002519516 343
# 1.4820100702195305e-10
# [0.49367141 0.24321544 0.24567443] 0.5000000250482559 344
# 1.4690404448458594e-10
# [0.49368063 0.24322531 0.24568072] 0.5000000249026335 345
# 1.4562240302495866e-10
# [0.49368981 0.24323515 0.24568699] 0.5000000247582782 346
# 1.4435530548695397e-10
# [0.49369895 0.24324494 0.24569323] 0.500000024615175 347
# 1.4310319595978171e-10
# [0.49370805 0.24325469 0.24569944] 0.5000000244733097 348
# 1.4186529728732467e-10
# [0.49371711 0.24326439 0.24570562] 0.500000024332668 349
# 1.4064172049188528e-10
# [0.49372614 0.24327406 0.24571178] 0.5000000241932357 350
# 1.3943224352885863e-10
# [0.49373512 0.24328368 0.24571791] 0.5000000240549992 351
# 1.3823653333133734e-10
# [0.49374406 0.24329326 0.24572401] 0.5000000239179447 352
# 1.3705447887701894e-10
# [0.49375297 0.2433028  0.24573009] 0.5000000237820589 353
# 1.358858581212985e-10
# [0.49376184 0.2433123  0.24573614] 0.5000000236473283 354
# 1.3473056004187356e-10
# [0.49377067 0.24332176 0.24574217] 0.5000000235137401 355
# 1.3358825157183674e-10
# [0.49377946 0.24333118 0.24574817] 0.5000000233812812 356
# 1.3245882168888556e-10
# [0.49378822 0.24334056 0.24575414] 0.5000000232499392 357
# 1.3134204834841512e-10
# [0.49379694 0.2433499  0.24576009] 0.5000000231197013 358
# 1.302379315504254e-10
# [0.49380562 0.24335921 0.24576602] 0.5000000229905551 359
# 1.2914613822800902e-10
# [0.49381427 0.24336847 0.24577192] 0.5000000228624887 360
# 1.2806644633656106e-10
# [0.49382288 0.24337769 0.2457778 ] 0.5000000227354899 361
# 1.2699874485377904e-10
# [0.49383145 0.24338688 0.24578365] 0.500000022609547 362
# 1.2594292275736052e-10
# [0.49383999 0.24339602 0.24578947] 0.5000000224846481 363
# 1.2489886902500302e-10
# [0.49384849 0.24340513 0.24579528] 0.5000000223607819 364
# 1.2386625058979917e-10
# [0.49385696 0.2434142  0.24580106] 0.500000022237937 365
# 1.2284484540714402e-10
# [0.4938654  0.24342324 0.24580681] 0.5000000221161022 366
# 1.2183487552164252e-10
# [0.49387379 0.24343224 0.24581254] 0.5000000219952663 367
# 1.208358968440848e-10
# [0.49388216 0.2434412  0.24581825] 0.5000000218754185 368
# 1.198477983521684e-10
# [0.49389049 0.24345012 0.24582393] 0.5000000217565481 369
# 1.1887035800128842e-10
# [0.49389878 0.24345901 0.2458296 ] 0.5000000216386445 370
# 1.1790357579144484e-10
# [0.49390705 0.24346786 0.24583523] 0.5000000215216972 371
# 1.169473407003352e-10
# [0.49391527 0.24347667 0.24584085] 0.5000000214056959 372
# 1.160013196610521e-10
# [0.49392347 0.24348545 0.24584644] 0.5000000212906304 373
# 1.1506551267359555e-10
# [0.49393163 0.24349419 0.24585201] 0.5000000211764907 374
# 1.1413969769336063e-10
# [0.49393976 0.2435029  0.24585756] 0.5000000210632668 375
# 1.1322387472034734e-10
# [0.49394786 0.24351158 0.24586309] 0.500000020950949 376
# 1.1231782170995075e-10
# [0.49395592 0.24352022 0.24586859] 0.5000000208395275 377
# 1.114214276398684e-10
# [0.49396396 0.24352882 0.24587407] 0.5000000207289931 378
# 1.1053447046549536e-10
# [0.49397196 0.24353739 0.24587953] 0.5000000206193362 379
# 1.0965683916452917e-10
# [0.49397992 0.24354593 0.24588497] 0.5000000205105475 380
# 1.0878875578157476e-10
# [0.49398786 0.24355443 0.24589039] 0.5000000204026179 381
# 1.0792955418281736e-10
# [0.49399577 0.2435629  0.24589578] 0.5000000202955385 382
# 1.0707945641286187e-10
# [0.49400364 0.24357134 0.24590115] 0.5000000201893001 383
# 1.0623835144940585e-10
# [0.49401149 0.24357974 0.24590651] 0.5000000200838942 384
# 1.0540590622554191e-10
# [0.4940193  0.24358811 0.24591184] 0.500000019979312 385
# 1.0458223176357251e-10
# [0.49402708 0.24359644 0.24591715] 0.500000019875545 386
# 1.0376699499659026e-10
# [0.49403483 0.24360475 0.24592244] 0.5000000197725846 387
# 1.0296041796920008e-10
# [0.49404256 0.24361302 0.24592771] 0.5000000196704225 388
# 1.0216205659219213e-10
# [0.49405025 0.24362126 0.24593296] 0.5000000195690506 389
# 1.013719108655664e-10
# [0.49405791 0.24362947 0.24593819] 0.5000000194684606 390
# 1.0058998078932291e-10
# [0.49406554 0.24363765 0.2459434 ] 0.5000000193686447 391

# %%
import torch
from torch.autograd.functional import hessian

# %%
import scipy

# %%
import numdifftools

# %%
hessian_mat=numdifftools.Hessian(func_ND)([0.5, 0.25,0.25])

# %%
eigen_val,eigen_vec=eigenvalues_eigenvector(hessian_mat)

# %%
eigen_val
# Out:
# array([ 7.71146662e-12, -5.30142979e-13, -1.14448811e-11])

# %%
eigen_vec
# Out:
# array([[ 0.63649123, -0.19220055,  0.74695238],
#        [-0.60449459,  0.4771708 ,  0.63788269],
#        [ 0.47902526,  0.85753541, -0.18753084]])

# %%
#conjugate directions from conjugate gradient descent

ans1[2][-1,:]
# Out:
# array([ 2.91226534e-05, -2.23551962e-05,  8.98194231e-06])
